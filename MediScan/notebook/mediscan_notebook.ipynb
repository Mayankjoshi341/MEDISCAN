# %%
import pandas as pd
from src.utils.config import RAW_DATA_DIR 
from src.data.load_data import load_data , load_detail_data

# %%
main_df = load_data(RAW_DATA_DIR) # main dataset loading
dis_df , pre_df , home_df= load_detail_data(RAW_DATA_DIR) # additional dataset loading
# Out:
# data loaded successfully.

# %%
main_df.head()
# Out:
#             Disease   Symptom_1  ... Symptom_16 Symptom_17
# 0  Fungal infection     itching  ...        NaN        NaN
# 1  Fungal infection   skin_rash  ...        NaN        NaN
# 2  Fungal infection     itching  ...        NaN        NaN
# 3  Fungal infection     itching  ...        NaN        NaN
# 4  Fungal infection     itching  ...        NaN        NaN
#
# [5 rows x 18 columns]

# %%
main_df.shape
# Out:
# (4920, 18)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom_1   4920 non-null   object
#  2   Symptom_2   4920 non-null   object
#  3   Symptom_3   4920 non-null   object
#  4   Symptom_4   4572 non-null   object
#  5   Symptom_5   3714 non-null   object
#  6   Symptom_6   2934 non-null   object
#  7   Symptom_7   2268 non-null   object
#  8   Symptom_8   1944 non-null   object
#  9   Symptom_9   1692 non-null   object
#  10  Symptom_10  1512 non-null   object
#  11  Symptom_11  1194 non-null   object
#  12  Symptom_12  744 non-null    object
#  13  Symptom_13  504 non-null    object
#  14  Symptom_14  306 non-null    object
#  15  Symptom_15  240 non-null    object
#  16  Symptom_16  192 non-null    object
#  17  Symptom_17  72 non-null     object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %%
main_df["Disease"].value_counts()
# Out:
# Disease
# Fungal infection                           120
# Allergy                                    120
# GERD                                       120
# Chronic cholestasis                        120
# Drug Reaction                              120
# Peptic ulcer diseae                        120
# AIDS                                       120
# Diabetes                                   120
# Gastroenteritis                            120
# Bronchial Asthma                           120
# Hypertension                               120
# Migraine                                   120
# Cervical spondylosis                       120
# Paralysis (brain hemorrhage)               120
# Jaundice                                   120
# Malaria                                    120
# Chicken pox                                120
# Dengue                                     120
# Typhoid                                    120
# hepatitis A                                120
# ...

# %%
from src.data.load_data import load_data
df = load_data(RAW_DATA_DIR)
# Out:
# data loaded successfully.

# %%
from src.data.clean_data import data_clean
df = data_clean(df)
# Out:
# Data cleaning is complete successfully

# %%
from src.data.split_data import features_split
X , y = features_split(df)
# Out:
# features split is complete successfully.

# %%
from src.features.train_test_split import train_test_split_data
X_train , X_test , y_train, y_test = train_test_split_data(X, y , train_size=0.8)

# %%
from src.features.encoding import symptoms_extract , y_scaler , x_encoding , x_test_encoding , y_test_scaling
symptoms = symptoms_extract(X)
X_train  , mlb= x_encoding(X_train)
encoder ,y_train = y_scaler(y_train)
X_test = x_test_encoding(X_test , mlb)
y_test = y_test_scaling(y_test , encoder)
# Out:
# X encoding is complete sucessfully.
# Y feature encoding complete successfully.
# X test encoding is complete sucessfully.
# Y test encoding complete successfully.

# %%
from src.tuning.model_tuning import model_selection
best_model  , model , model_scores_dict = model_selection(X_train , y_train)
# Out:
# logistic regression: mean=100.00, std=0.000
# Decision tree : mean=100.00, std=0.000
# Random Forest: mean=100.00, std=0.000

# %%
from src.tuning.hyperparameter_tuning import tune_logistic_regression , tune_random_forest , best_hyperparameters
lr_model, lr_score, lr_params= tune_logistic_regression(X_train , y_train)
rf_model, rf_score, rf_params = tune_random_forest(X_train , y_train)
model = best_hyperparameters(lr_model, lr_score, rf_model, rf_score)
# Out:
# Best Model: Random Forest with score 1.0

# %%
print("LR:", lr_score, lr_params)
print("RF:", rf_score, rf_params)
# Out:
# LR: 1.0 {'solver': 'lbfgs', 'max_iter': 500, 'C': 0.01}
# RF: 1.0 {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}

# %%
from src.prediction.processing_input import transform_input ,  input_sysptoms
from src.prediction.prediction import home_remedies , predicted_disease

selected_symptoms = ['chest pain','back pain']
input_data = input_sysptoms(selected_symptoms)

input_encoded = transform_input(input_data , mlb)

pred = predicted_disease(input_encoded , model , encoder)
remidies , s_level , redation_ad = home_remedies(home_red , pred)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 10
#       7 input_encoded = transform_input(input_data , mlb)
#       9 pred = predicted_disease(input_encoded , model , encoder)
# ---> 10 remidies , s_level , redation_ad = home_remedies(home_red , pred)
#
# File c:\Users\mayan\gitrepos\MEDISCAN\MediScan\src\prediction\prediction.py:40, in home_remedies(homecare_df, disease_name)
#      38     remedies.append(row["home_remedy_2"])
#      39     remedies.append(row["home_remedy_3"])
# ---> 40 severity_level = disease_row["severity_level"].values[0]
#      41 reaction_advice = disease_row["reaction_advice"].values[0]
#      43 return remedies , severity_level , reaction_advice
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
home_red.shape
# Out:
# (41, 6)

# %%
df.

# %%
home_red
# Out:
#                               disease_name                  home_remedy_1  \
# 0                            Drug Reaction  Stop suspected drug (if safe)
# 1                                  Malaria                  Stay hydrated
# 2                                  Allergy                  Avoid trigger
# 3                           Hypothyroidism               Iodine-rich diet
# 4                                Psoriasis                Moisturize skin
# 5                                     GERD               Avoid spicy food
# 6                      Chronic cholestasis                   Low-fat diet
# 7                              hepatitis A                           Rest
# 8                          Osteoarthristis                   Hot compress
# 9   (vertigo) Paroymsal Positional Vertigo                 Epley maneuver
# 10                            Hypoglycemia                  Consume sugar
# 11                                    Acne            Wash face regularly
# ...

# %%
home_red.iloc[40]
# Out:
# disease_name                            Drug Reaction
# home_remedy_1                         Nutritious diet
# home_remedy_2                               Isolation
# home_remedy_3                                    Rest
# severity_level                     Level 5 - Critical
# reaction_advice    Strict anti-TB treatment mandatory
# Name: 40, dtype: object

# %%
home_red[home_red["disease_name"] == "Drug Reaction"]
# Out:
#      disease_name                  home_remedy_1  \
# 0   Drug Reaction  Stop suspected drug (if safe)
# 1   Drug Reaction                  Stay hydrated
# 2   Drug Reaction                  Avoid trigger
# 3   Drug Reaction               Iodine-rich diet
# 4   Drug Reaction                Moisturize skin
# 5   Drug Reaction               Avoid spicy food
# 6   Drug Reaction                   Low-fat diet
# 7   Drug Reaction                           Rest
# 8   Drug Reaction                   Hot compress
# 9   Drug Reaction                 Epley maneuver
# 10  Drug Reaction                  Consume sugar
# 11  Drug Reaction            Wash face regularly
# 12  Drug Reaction                 Low sugar diet
# 13  Drug Reaction            Clean affected area
# 14  Drug Reaction                  Low salt diet
# 15  Drug Reaction               Avoid spicy food
# 16  Drug Reaction                High fiber diet
# 17  Drug Reaction               Steam inhalation
# ...

# %%
predicted_disease(input_encoded , model , encoder)
dict = top_3_predictions(input_encoded , model , encoder)
print("Top 3 Predicted Diseases and Probabilities:", dict)
for disease, prob in dict:
    print(f"{disease}: {prob*100:.2f}%")
dis = disease_description(full_data['description'] , "Heart attack")
pre_list = disease_precautions(full_data['precaution'] , "Heart attack")
remedies_list , s_level , reaction_advi = home_remedies(homecare_df= home_red , disease_name= "Heart attack")
print(pre_list)
print("-"*30)
for remedis in remedies_list:
    print(remedis)
print(s_level)
print("-"*30)
print(reaction_advi)

# %%
x = home_red[home_red["disease_name"]== "Drug Reaction"]
y = x["reaction_advice"].values
print(y)

# %%
dis

# %%
pred = model.predict(input_encoded)[0]
decoded_pred = encoder.inverse_transform([pred])
print("Predicted Disease:", decoded_pred[0])
print("predicted probabilities:", )

# %%
probs = model.predict_proba(input_encoded)

top3_indices = np.argsort(probs[0])[::-1][:3]

top3_probs = probs[0][top3_indices]

top3_diseases = model.classes_[top3_indices]

for disease, prob in zip(top3_diseases, top3_probs):
    disease_name = encoder.inverse_transform([disease])[0]
    print(f"{disease_name}: {prob*100:.2f}%")
